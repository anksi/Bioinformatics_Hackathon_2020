# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('GTEx_pancreas_liver_images_liverfat_pancreasfat.xlsx', index_col=0)
cols = [
    'Sex',
    'Age.Bracket',
    'Hardy.Scale',
    'Pathology.Categories_pancreas',
    'Pathology.Categories_liver',
    'Fat.Percentage_liver',
    'Fat.Percentage_pancreas'
       ]
df1 = df[cols]
df1
# Out:
#                Sex Age.Bracket                  Hardy.Scale  \
# Subject.ID
# GTEX-1117F  female       60-69                   Slow death
# GTEX-111FC    male       60-69         Fast death - violent
# GTEX-111VG    male       60-69           Intermediate death
# GTEX-113JC  female       50-59  Fast death - natural causes
# GTEX-117XS    male       60-69  Fast death - natural causes
# ...            ...         ...                          ...
# GTEX-ZYVF   female       50-59              Ventilator case
# GTEX-ZYW4     male       60-69           Intermediate death
# GTEX-ZYWO   female       40-49              Ventilator case
# GTEX-ZYY3   female       60-69                   Slow death
# GTEX-ZZPT     male       50-59                   Slow death
#
#            Pathology.Categories_pancreas         Pathology.Categories_liver  \
# Subject.ID
# GTEX-1117F                saponification                           necrosis
# GTEX-111FC                           NaN                         congestion
# GTEX-111VG                           NaN             fibrosis, inflammation
# GTEX-113JC                           NaN                          steatosis
# GTEX-117XS                           NaN  fibrosis, inflammation, steatosis
# ...                                  ...                                ...
# GTEX-ZYVF                 saponification                          steatosis
# GTEX-ZYW4                            NaN                           fibrosis
# GTEX-ZYWO                            NaN                                NaN
# GTEX-ZYY3                 saponification              congestion, steatosis
# GTEX-ZZPT                 saponification              cirrhosis, nodularity
#
#             Fat.Percentage_liver  Fat.Percentage_pancreas
# Subject.ID
# GTEX-1117F             28.672134                26.688684
# GTEX-111FC             33.668883                 9.667266
# GTEX-111VG             32.850612                43.050468
# GTEX-113JC             31.373621                 5.533414
# GTEX-117XS             29.382420                45.074451
# ...                          ...                      ...
# GTEX-ZYVF              30.932393                13.681926
# GTEX-ZYW4              34.370814                14.931241
# GTEX-ZYWO              19.809008                 3.031982
# GTEX-ZYY3              34.810192                18.113399
# GTEX-ZZPT              34.695932                10.284363
#
# [577 rows x 7 columns]

# %%
categorical_features = [
    'Sex',
    'Age.Bracket',
    'Hardy.Scale',
]

fig, ax = plt.subplots(1, len(categorical_features), figsize=(16,9))
for i, categorical_feature in enumerate(df[categorical_features]):
    df[categorical_feature].value_counts().plot(kind = "bar", ax=ax[i]).set_title(categorical_feature)
    plt.tight_layout()
fig.show()
# Out:
# C:\Users\simon\Anaconda3\envs\biohackathon2020\lib\site-packages\ipykernel_launcher.py:11: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # This is added back by InteractiveShellApp.init_path()

# %%
categorical_features = [
    'Pathology.Categories_pancreas',
    'Pathology.Categories_liver'
]

fig, ax = plt.subplots(1, len(categorical_features), figsize=(16,9))
for i, categorical_feature in enumerate(df[categorical_features]):
    df[categorical_feature].value_counts().plot(kind = "bar", ax=ax[i]).set_title(categorical_feature)
    plt.tight_layout()
fig.show()
# Out:
# C:\Users\simon\Anaconda3\envs\biohackathon2020\lib\site-packages\ipykernel_launcher.py:10: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   # Remove the CWD from sys.path while we load stuff.

# %%
df[['Fat.Percentage_liver']].sort_values('Fat.Percentage_liver').plot(kind='bar', figsize=(16,9))
